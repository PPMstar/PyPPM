# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0,'/user/cedar_scratch_djstephe/PyPPM/ppmpy')
from ppmpy import ppm
from matplotlib import pyplot as plt
# %matplotlib nbagg
from nugridpy import utils
cb = utils.colourblind

# %% [markdown]
# ## Initialization of MomsDataSet and RprofSet

# %%
# directory with momsdata and rprofs
dir_moms = '/user/cedar_scratch_djstephe/astrohub-moms-example/prfs/frombqavs'
dir_rprof = '/user/cedar_scratch_djstephe/astrohub-moms-example/prfs/'

moms = ppm.MomsDataSet(dir_moms)
rprof = ppm.RprofSet(dir_rprof)
# Out:
# 22 momsdata rprof files found in '/user/cedar_scratch_djstephe/astrohub-moms-example/prfs/frombqavs/.
# Dump numbers range from 0 to 310.
# ...
# 698 rprof files found in '/user/cedar_scratch_djstephe/astrohub-moms-example/prfs/.
# Dump numbers range from 0 to 697.
# Reading history file '/user/cedar_scratch_djstephe/astrohub-moms-example/prfs/HcoreE00768-0000.hstry'.

# %% [markdown]
# We are missing some of the dump files from a moms data re-run which is typical. I can check what dumps are available with a method of the MomsDataSet class

# %%
moms.get_dump_list()

# %% [markdown]
# ## Compare Rprof's with Moms

# %% [markdown]
# The initial state in the two should more or less be the same but are probably a little bit different because of the averaging. You do not have to store the radius values in the moms data but it is probably a good idea to!

# %%
len(rprof_r[::4])
# Out:
# 96

# %%
# look at initial stratification
model_num = 0

moms_r = moms.get('rxxxxxxx',model_num)
moms_A = moms.get('Atotxxxx',model_num)
moms_rho = moms.get('rhototxx',model_num)
moms_pr = moms.get('ptotxxxx',model_num)

rprof_r = rprof.get('R',model_num,resolution='l')
rprof_A = rprof.get('A',model_num)
rprof_rho = rprof.get('Rho0',model_num,resolution='l')
rprof_pr = rprof.get('P0')

# %%
ifig = 0
plt.close(ifig); plt.figure(ifig)

plt.plot(moms_r,moms_A)
plt.plot(rprof_r,rprof_A)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ifig += 1; plt.close(ifig); plt.figure(ifig)

plt.plot(rprof_r[::4],moms_rho)
plt.plot(rprof_r,rprof_rho)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ifig += 1; plt.close(ifig-1); plt.figure(ifig)

plt.plot(rprof_r[::4],moms_p)
plt.plot(rprof_r,rprof_rho)
# Out:
# <img src="data:image/png;base64,..." width="640">
