# %%
# %pylab nbagg
import os
import ppm
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
YProfile_dir = '/rpod2/PPM/YProfiles/'
os.listdir(YProfile_dir)
# Out:
# ['agb-entrainment-convergence',
#  'RAWD',
#  'sakurai',
#  'O-shell-M25',
#  'AGBTPM2.0Z1.e-5',
#  'sakurai-num-exp-robustness-onset-GOSH']

# %%
project_dir = os.listdir(YProfile_dir)[3]
print project_dir
# Out:
# O-shell-M25

# %%
#reload(ppm)
ppm.set_YProf_path(os.path.join(YProfile_dir,project_dir))

# %%
print ppm.ppm_path
print ppm.cases
# Out:
# /rpod2/PPM/YProfiles/O-shell-M25
# ['D10', 'D11', 'D14', 'D4', 'D1_toomuchoutput', 'D5', 'D2_dump94-112-notviolent', 'D3', 'D9', 'D13', 'D8', 'D1', 'D6', 'D12', 'D2']

# %%
ppm.set_nice_params()
# Out:
# /usr/lib64/python2.7/site-packages/matplotlib/__init__.py:855: UserWarning: text.fontsize is deprecated and replaced with font.size; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# ## High-res standard run

# %%
d2=ppm.yprofile('D2') # O-shell 1536^3 case
# Out:
# Reading attributes from file  YProfile-01-0134.bobaaa
# Analyzing headers ...
# There are 135 YProfile files in the /rpod2/PPM/YProfiles/O-shell-M25/D2 directory.
# Ndump values range from 0 to 134
# Time values range from 0.0 to 1340.0

# %%
# figure out where we want to put the convective boundary
ifig=10;close(ifig);figure(ifig)
d2.plot('Y','A',fname=120)
# Out:
# <img src="data:image/png;base64,...">

# %%
rtop=8.15
ifig=11;close(ifig);figure(ifig)
d2.Richardson_plot(fname1=0, fname2= 120, R_top = rtop)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## O-shell case with 50 times heating rate

# %%
reload(ppm)
d10=ppm.yprofile('D10') # O-shell 50x heat, 768^3 case
# Out:
# Reading attributes from file  YProfile-01-0262.bobaaa
# Analyzing headers ...
# There are 263 YProfile files in the /rpod2/PPM/YProfiles/O-shell-M25/D10 directory.
# Ndump values range from 0 to 262
# Time values range from 0.0 to 2620.0

# %%
# find the top of the convection zone
ifig=50;close(ifig);figure(ifig)
d10.plot('Y','A',fname=120)
# Out:
# <img src="data:image/png;base64,...">

# %%
ifig=12;close(ifig);figure(ifig)
d10.vprofs(120,ifig=12)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
rtop=8.88
ifig=51;close(ifig);figure(ifig)
d10.Richardson_plot(fname1=0, fname2= 120, R_top = rtop,ylim_max=2.4)
legend(loc=3)
# Out:
# <img src="data:image/png;base64,...">

# %%
d2.Richardson_plot?
